# %% [markdown]
# # **AirBnb Bookings Analysis**

# %% [markdown]
# ##### **Project Type**    - Exploratory Data Analysis [EDA]
#
# ---
#
#
# ##### **Contribution**    - Individual
#
# ---
# ##### **Name** - Dev Deopuria

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project focuses on analyzing Airbnb data from New York City. The primary aim of the analysis is to extract meaningful insights and identify patterns that can assist both travelers and hosts in making informed decisions. Additionally, the analysis seeks to offer strategic recommendations for improving Airbnb operations and business growth. By examining variables such as listing counts, neighborhood groups, prices, reviews, and room types, the study highlights key trends and actionable insights that benefit stakeholders.
#
# The project began with an essential step of data exploration and cleaning. This process involved evaluating data types, handling missing values, addressing inconsistencies, and removing outliers to ensure that the dataset was of high quality and ready for analysis. With the cleaned dataset, relationships between variables were examined systematically, and visualizations were created to uncover significant trends. Graphs and charts proved crucial in identifying patterns, such as preferred neighborhoods, room type preferences, price ranges, and factors influencing availability and pricing. Factors like minimum stay requirements, review counts, and host listing volumes were found to be pivotal in shaping pricing and availability trends.
#
# For conducting the analysis, various tools and libraries were utilized. Pandas played a key role in data manipulation and wrangling, enabling efficient organization of the dataset. NumPy was employed for numerical computations, providing essential support in analyzing numerical data. Visualization tools, including Matplotlib and Seaborn, were instrumental in creating clear, visually appealing charts that made the findings easier to understand and interpret for stakeholders. These visualizations facilitated better communication of the insights and enabled stakeholders to make informed, actionable decisions. The findings of the analysis were insightful and practical. Guest preferences for room types and price ranges were identified, along with actionable suggestions for hosts to improve their listings and attract more bookings. For instance, a proposed filtering system could allow guests to search for accommodations tailored to their specific needs, such as budget or desired location. Additionally, introducing a ranking system for hosts, based on their ability to meet guest expectations, could enhance the overall user experience by fostering greater alignment between guest needs and host offerings. These recommendations aim to improve customer satisfaction and create a more seamless Airbnb experience for both parties.
#
# From a personal perspective, this project was an enriching learning experience. It provided a deeper understanding of Airbnb’s operational model and the challenges involved in analyzing real-world data. The project also allowed me to enhance my technical skills in data science, including the effective use of libraries for data analysis and visualization, as well as crafting meaningful narratives from data. Moreover, it encouraged critical thinking and problem-solving, which were essential in interpreting complex datasets and deriving actionable insights.
#
# In conclusion, this project not only uncovered important insights into Airbnb data but also provided strategies to improve operations for both hosts and guests. By addressing real-world complexities, the analysis offered valuable learning opportunities, helping me develop both technical and analytical skills. This experience has significantly contributed to my academic growth, preparing me to tackle similar challenges in future research and professional endeavors.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **The objective of this project is to analyze the given dataset to extract valuable insights that stakeholders can utilize to drive business improvements and make informed decisions.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of this project is to analyze data to identify opportunities for improvement and gain a deeper understanding of customer preferences and behaviors.
#
# The aim is to generate actionable insights that align with customer needs, enhance satisfaction, and support informed decision-making. These insights will also contribute to improving operational efficiency and driving overall business growth with a customer-centric approach.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import math
import seaborn as sns
import openpyxl
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
'''Creating a dataframe of the given dataset'''
airbnb_df = pd.DataFrame(pd.read_csv("/Airbnb NYC 2019.csv"))

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df.head(5)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room  149.0             1.0                9.0  2018-10-19
# 1  Entire home/apt  225.0             1.0               45.0  2019-05-21
# 2     Private room  150.0             3.0                0.0         NaN
# 3  Entire home/apt   89.0             1.0              270.0  2019-07-05
# 4  Entire home/apt   80.0            10.0                9.0  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                             6.0             365.0
# 1               0.38                             2.0             355.0
# 2                NaN                             1.0             365.0
# 3               4.64                             1.0             194.0
# 4               0.10                             1.0               0.0

# %% [markdown]
# As we can see here is the first look of our dataset on which we will be working, let's dive deep into it.

# %%
# Let's check for all the columns we have in our dataset.
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# Here is the list of all our columns in the dataset.

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb_df.shape
# Out:
# (7391, 16)

# %% [markdown]
# Looking at the shape of our dataset we can see that the number of rows is significantly high as compared to the number of columns.
# We have:-
# rows = 48895
# columns = 16

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7391 entries, 0 to 7390
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              7391 non-null   int64
#  1   name                            7384 non-null   object
#  2   host_id                         7391 non-null   int64
#  3   host_name                       7386 non-null   object
#  4   neighbourhood_group             7391 non-null   object
#  5   neighbourhood                   7391 non-null   object
#  6   latitude                        7391 non-null   float64
#  7   longitude                       7391 non-null   float64
#  8   room_type                       7390 non-null   object
#  9   price                           7390 non-null   float64
#  10  minimum_nights                  7390 non-null   float64
#  11  number_of_reviews               7390 non-null   float64
#  12  last_review                     6567 non-null   object
#  13  reviews_per_month               6567 non-null   float64
#  14  calculated_host_listings_count  7390 non-null   float64
#  15  availability_365                7390 non-null   float64
# dtypes: float64(8), int64(2), object(6)
# memory usage: 924.0+ KB

# %% [markdown]
# Here we can see the division of Categorical and Numerical values in our dataset, We can see:-
#
# - 3 columns have float64 data values (Numerical)
# - 7 columns have int64 data type values (Numerical)
# - 6 columns have object data type values (Categorical)

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicated_values = airbnb_df[airbnb_df.duplicated()]
duplicated_values
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# With this we can see that there are no exact duplicate values, however we need to check for other columns as well, like id and name, as these values are not likely to be same.

# %%
# Let us first check for 'id' column.
duplicated_id = airbnb_df[airbnb_df.duplicated(subset=['id'])]
duplicated_id
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %% [markdown]
# As we can see there is no dulicated 'id's in our dataset.

# %%
# Now let us check for 'name' column.
duplicated_name = airbnb_df[airbnb_df.duplicated(subset=['name'])]
duplicated_name
# Out:
#            id                                               name   host_id  \
# 330     81739                  Loft w/ Terrace @ Box House Hotel    417504
# 339     84010                               Superior @ Box House    417504
# 580    219818                 ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿   1138692
# 661    250537                                The Lenox in Harlem   1313306
# 669    253471                   Loft Suite @ The Box House Hotel    417504
# 670    253475                   Loft Suite @ The Box House Hotel    417504
# 674    253800                       Loft Suite @ Box House Hotel    417504
# 675    253803                   Loft Suite @ The Box House Hotel    417504
# 676    253806                   Loft Suite @ The Box House Hotel    417504
# 677    253811                   Loft Suite @ The Box House Hotel    417504
# 678    253815                   Loft Suite @ The Box House Hotel    417504
# 679    253828                Duplex w/ Terrace @ Box House Hotel    417504
# 680    253839                  Loft w/ Terrace @ Box House Hotel    417504
# 682    253846                               Superior @ Box House    417504
# 827    294227                   Loft Suite @ The Box House Hotel    417504
# 829    294242                   Loft Suite @ The Box House Hotel    417504
# 831    294259                       Loft Suite @ Box House Hotel    417504
# 832    294263                   Loft Suite @ The Box House Hotel    417504
# 833    294280                   Loft Suite @ The Box House Hotel    417504
# 836    294490                       Loft Suite @ Box House Hotel    417504
# 1098   464231                     Large Room w/ Private Entrance   1530310
# 1555   703971                                HOME AWAY FROM HOME   1785800
# 1772   798008                Hancock Town House!-Stuyvesant Mews    758441
# 2564  1330056                Spacious Loft 5 min to Union Square    124357
# 3245  1936633                Great 1BD waterfront City Island NY  10018391
# 3551  2118102                  Charming West Village One Bedroom   7579627
# 3581  2138787                    HARLEM, NEW YORK WELCOMES YOU!!     68428
# 3703  2232600                                                NaN  11395220
# 4233  2781747                     Beautiful brownstone apartment    309329
# 4352  2925138                            Steps from Central Park  14935685
# 4681  3283409                      Beautiful Brooklyn Brownstone  16593547
# 4715  3319483                           Room w/ Private Bathroom   1498951
# 4875  3479614                    Charming East Village Apartment   3395227
# 5243  3791244                       west village 1BR!best value!   2119276
# 5615  4084603                       Prime East Village 1 Bedroom   7861502
# 5775  4209595                                                NaN  20700823
# 5903  4303600  Luminous Modern Apt Share for Young Professionals   2822805
# 5975  4370230                                                NaN  22686810
# 6056  4431674                                HOME AWAY FROM HOME  21841949
# 6269  4581788                                                NaN  21600904
# 6499  4720460                    Charming Upper West Side Studio   1887912
# 6567  4756856                                                NaN   1832442
# 6605  4774658                                                NaN  24625694
# 6644  4787386                    Spacious East Village Apartment  24678971
# 6968  4995083                                East Village Studio  25748492
#
#                 host_name neighbourhood_group              neighbourhood  \
# 330   The Box House Hotel            Brooklyn                 Greenpoint
# 339   The Box House Hotel            Brooklyn                 Greenpoint
# 580          Keera (Jena)           Manhattan            Lower East Side
# 661                Yvette           Manhattan                     Harlem
# 669   The Box House Hotel            Brooklyn                 Greenpoint
# 670   The Box House Hotel            Brooklyn                 Greenpoint
# 674   The Box House Hotel            Brooklyn                 Greenpoint
# 675   The Box House Hotel            Brooklyn                 Greenpoint
# 676   The Box House Hotel            Brooklyn                 Greenpoint
# 677   The Box House Hotel            Brooklyn                 Greenpoint
# 678   The Box House Hotel            Brooklyn                 Greenpoint
# 679   The Box House Hotel            Brooklyn                 Greenpoint
# 680   The Box House Hotel            Brooklyn                 Greenpoint
# 682   The Box House Hotel            Brooklyn                 Greenpoint
# 827   The Box House Hotel            Brooklyn                 Greenpoint
# 829   The Box House Hotel            Brooklyn                 Greenpoint
# 831   The Box House Hotel            Brooklyn                 Greenpoint
# 832   The Box House Hotel            Brooklyn                 Greenpoint
# 833   The Box House Hotel            Brooklyn                 Greenpoint
# 836   The Box House Hotel            Brooklyn                 Greenpoint
# 1098              Jacques            Brooklyn         Bedford-Stuyvesant
# 1555               Marvet            Brooklyn  Prospect-Lefferts Gardens
# 1772                 Fred            Brooklyn         Bedford-Stuyvesant
# 2564                 Alex            Brooklyn               Williamsburg
# 3245                 Alex               Bronx                City Island
# 3551                Maria           Manhattan               West Village
# 3581      Tye And Etienne           Manhattan         Washington Heights
# 3703                 Anna           Manhattan               East Village
# 4233                Eilon            Brooklyn            Carroll Gardens
# 4352                 Uday           Manhattan             Hell's Kitchen
# 4681          Mary & Josh            Brooklyn         Bedford-Stuyvesant
# 4715              Yolanda            Brooklyn                   Bushwick
# 4875                Brian           Manhattan               East Village
# 5243                 Host           Manhattan               West Village
# 5615                Aviad           Manhattan               East Village
# 5775                Jesse           Manhattan          Greenwich Village
# 5903                Ollie            Brooklyn         Bedford-Stuyvesant
# 5975              Michaël           Manhattan                     Nolita
# 6056              Patwell           Manhattan                     Harlem
# 6269                Lucie            Brooklyn               Williamsburg
# 6499                 Anna           Manhattan            Upper West Side
# 6567             Carolina            Brooklyn                   Bushwick
# 6605                 Josh           Manhattan         Washington Heights
# 6644                  Nir           Manhattan               East Village
# 6968                David           Manhattan               East Village
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 330   40.73842  -73.95312     Private room  249.0             3.0
# 339   40.73813  -73.95394     Private room  179.0             3.0
# 580   40.71892  -73.98401  Entire home/apt  199.0             1.0
# 661   40.81122  -73.94279  Entire home/apt  400.0             5.0
# 669   40.73641  -73.95330  Entire home/apt  199.0             3.0
# 670   40.73794  -73.95254  Entire home/apt  199.0             3.0
# 674   40.73730  -73.95323  Entire home/apt  199.0             3.0
# 675   40.73708  -73.95271  Entire home/apt  199.0             3.0
# 676   40.73652  -73.95236  Entire home/apt  199.0             3.0
# 677   40.73693  -73.95316  Entire home/apt  199.0             3.0
# 678   40.73784  -73.95324  Entire home/apt  199.0             3.0
# 679   40.73674  -73.95247     Private room  349.0             3.0
# 680   40.73783  -73.95259     Private room  249.0             3.0
# 682   40.73731  -73.95450     Private room  179.0             3.0
# 827   40.73683  -73.95430  Entire home/apt  199.0             3.0
# 829   40.73890  -73.95395  Entire home/apt  199.0             3.0
# 831   40.73806  -73.95462  Entire home/apt  199.0             3.0
# 832   40.73661  -73.95479  Entire home/apt  199.0             3.0
# 833   40.73857  -73.95435  Entire home/apt  199.0             3.0
# 836   40.73857  -73.95299  Entire home/apt  199.0             3.0
# 1098  40.68905  -73.95410     Private room   65.0             7.0
# 1555  40.65820  -73.95275     Private room   70.0             5.0
# 1772  40.68561  -73.92029     Private room  165.0             1.0
# 2564  40.71571  -73.95813     Private room   90.0             1.0
# 3245  40.85258  -73.78762  Entire home/apt  120.0             3.0
# 3551  40.73236  -74.00353  Entire home/apt  200.0             1.0
# 3581  40.83191  -73.94110     Private room   62.0             2.0
# 3703  40.73215  -73.98821  Entire home/apt  200.0             1.0
# 4233  40.68235  -74.00047  Entire home/apt  150.0             2.0
# 4352  40.76761  -73.98497  Entire home/apt  250.0             1.0
# 4681  40.68562  -73.92375  Entire home/apt  139.0             2.0
# 4715  40.70247  -73.92061     Private room   65.0             1.0
# 4875  40.72402  -73.98771  Entire home/apt  179.0             5.0
# 5243  40.73254  -74.00698  Entire home/apt  170.0            30.0
# 5615  40.72878  -73.98521  Entire home/apt  200.0             1.0
# 5775  40.73473  -73.99244  Entire home/apt  225.0             1.0
# 5903  40.68531  -73.95185     Private room   60.0            30.0
# 5975  40.72046  -73.99550  Entire home/apt  215.0             7.0
# 6056  40.80066  -73.95147  Entire home/apt  150.0             2.0
# 6269  40.71370  -73.94378     Private room  150.0             1.0
# 6499  40.78657  -73.97161  Entire home/apt  150.0            30.0
# 6567  40.70046  -73.92825     Private room   70.0             1.0
# 6605  40.85198  -73.93108     Private room   40.0             1.0
# 6644  40.72454  -73.98688     Private room  175.0             1.0
# 6968  40.72954  -73.98337  Entire home/apt  120.0             1.0
#
#       number_of_reviews last_review  reviews_per_month  \
# 330                 2.0  2011-05-12               0.02
# 339                13.0  2019-06-27               0.14
# 580                14.0  2015-07-20               0.15
# 661                 0.0         NaN                NaN
# 669                24.0  2018-11-06               0.32
# 670                59.0  2019-06-24               0.66
# 674                24.0  2019-04-25               0.26
# 675                23.0  2019-06-22               0.26
# 676                43.0  2019-07-02               0.47
# 677                30.0  2019-07-03               0.32
# 678                39.0  2019-06-29               0.44
# 679                 8.0  2018-07-26               0.09
# 680                 3.0  2015-11-03               0.03
# 682                 4.0  2015-12-04               0.05
# 827                43.0  2019-06-22               0.49
# 829                75.0  2019-06-05               0.93
# 831                73.0  2019-06-30               0.84
# 832                89.0  2019-07-01               1.06
# 833                23.0  2019-04-23               0.26
# 836                54.0  2019-06-10               0.61
# 1098                2.0  2012-05-29               0.02
# 1555               18.0  2019-05-30               0.22
# 1772                0.0         NaN                NaN
# 2564              115.0  2019-05-21               1.63
# 3245               84.0  2018-12-01               1.26
# 3551                4.0  2016-12-22               0.06
# 3581                4.0  2019-04-01               0.19
# 3703               28.0  2015-06-08               0.45
# 4233               52.0  2019-07-01               1.33
# 4352                0.0         NaN                NaN
# 4681              124.0  2019-06-25               2.09
# 4715                0.0         NaN                NaN
# 4875               72.0  2016-11-22               1.18
# 5243               12.0  2018-08-12               0.22
# 5615                1.0  2015-05-24               0.02
# 5775                1.0  2015-01-01               0.02
# 5903               44.0  2019-05-19               0.78
# 5975                5.0  2016-01-02               0.09
# 6056               36.0  2018-11-06               0.78
# 6269                0.0         NaN                NaN
# 6499               31.0  2019-05-21               0.59
# 6567                0.0         NaN                NaN
# 6605                0.0         NaN                NaN
# 6644               41.0  2016-07-24               0.77
# 6968                8.0  2016-05-30               0.18
#
#       calculated_host_listings_count  availability_365
# 330                             28.0              60.0
# 339                             28.0              81.0
# 580                              2.0             158.0
# 661                              2.0             365.0
# 669                             28.0              84.0
# 670                             28.0              60.0
# 674                             28.0              60.0
# 675                             28.0              60.0
# 676                             28.0              60.0
# 677                             28.0              56.0
# 678                             28.0              84.0
# 679                             28.0              58.0
# 680                             28.0              60.0
# 682                             28.0              81.0
# 827                             28.0              84.0
# 829                             28.0              84.0
# 831                             28.0              56.0
# 832                             28.0              62.0
# 833                             28.0              81.0
# 836                             28.0              60.0
# 1098                             3.0               0.0
# 1555                             3.0             365.0
# 1772                             4.0               0.0
# 2564                             3.0             359.0
# 3245                             1.0              16.0
# 3551                             1.0               0.0
# 3581                             2.0             336.0
# 3703                             1.0             341.0
# 4233                             1.0              53.0
# 4352                             1.0               0.0
# 4681                             1.0             231.0
# 4715                             1.0               5.0
# 4875                             1.0               0.0
# 5243                            39.0             252.0
# 5615                             1.0               0.0
# 5775                             1.0               0.0
# 5903                             8.0              99.0
# 5975                             1.0               0.0
# 6056                             2.0               0.0
# 6269                             1.0               0.0
# 6499                             1.0             213.0
# 6567                             1.0               0.0
# 6605                             1.0               0.0
# 6644                             1.0               0.0
# 6968                             1.0               0.0

# %% [markdown]
# Now as we can see we have 998 rows that are duplicates, this might be due to some changes to get an idea for the reason of these duplicated values, let us observe any one of the rows.

# %%
# We can check for any specific row having the name value included in the duplicated data, using the query command.
# Let's check for where name is 'Superior @ Box House', which is in our duplicated data.
airbnb_df.query('name == "Superior @ Box House"')
# Out:
#          id                  name  host_id            host_name  \
# 321   77765  Superior @ Box House   417504  The Box House Hotel
# 339   84010  Superior @ Box House   417504  The Box House Hotel
# 682  253846  Superior @ Box House   417504  The Box House Hotel
#
#     neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 321            Brooklyn    Greenpoint  40.73749  -73.95292  Private room
# 339            Brooklyn    Greenpoint  40.73813  -73.95394  Private room
# 682            Brooklyn    Greenpoint  40.73731  -73.95450  Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 321  179.0             3.0               36.0  2019-07-01               0.36
# 339  179.0             3.0               13.0  2019-06-27               0.14
# 682  179.0             3.0                4.0  2015-12-04               0.05
#
#      calculated_host_listings_count  availability_365
# 321                            28.0              79.0
# 339                            28.0              81.0
# 682                            28.0              81.0

# %% [markdown]
# Here we can observe that almost all the values are same except for the id, latitude, longitude, number_of_reviews, reviews_per_month, availability_365.
# However these columns can be different, and they are not so important.

# %%
# To tackle this issue we will create a new data frame in which we will include
# only those columns which are really important for us.
airbnb_df = airbnb_df[['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
       'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
       'minimum_nights', 'number_of_reviews', 'last_review',
       'reviews_per_month', 'calculated_host_listings_count',
       'availability_365']].copy()

# %% [markdown]
# Now that we have created this dataframe we will be able to handle duplicated values more efficiently.

# %%
# Let's check for the duplicated values of any other row.
airbnb_df.query('name == "Loft w/ Terrace @ Box House Hotel"')
# Out:
#          id                               name  host_id            host_name  \
# 328   80700  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
# 330   81739  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
# 680  253839  Loft w/ Terrace @ Box House Hotel   417504  The Box House Hotel
#
#     neighbourhood_group neighbourhood  latitude  longitude     room_type  \
# 328            Brooklyn    Greenpoint  40.73738  -73.95482  Private room
# 330            Brooklyn    Greenpoint  40.73842  -73.95312  Private room
# 680            Brooklyn    Greenpoint  40.73783  -73.95259  Private room
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 328  349.0             3.0                7.0  2019-05-24               0.07
# 330  249.0             3.0                2.0  2011-05-12               0.02
# 680  249.0             3.0                3.0  2015-11-03               0.03
#
#      calculated_host_listings_count  availability_365
# 328                            28.0              60.0
# 330                            28.0              60.0
# 680                            28.0              60.0

# %% [markdown]
# As we can see here each and every value is almost the same, except for the prices, there might be a chances that the prices were altered as per the market condition due however the hotel is the same.

# %%
# In this case we will seek out the duplicated values for those columns which
# are concerning and may effect the data if duplicated.

# Checking for the values where - 'name', 'host_name','neighbourhood_group', 'neighbourhood', 'room_type' are duplicated.
airbnb_df.loc[airbnb_df.duplicated(subset= ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'])]
# Out:
#            id                                               name  host_id  \
# 330     81739                  Loft w/ Terrace @ Box House Hotel   417504
# 339     84010                               Superior @ Box House   417504
# 580    219818                 ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692
# 669    253471                   Loft Suite @ The Box House Hotel   417504
# 670    253475                   Loft Suite @ The Box House Hotel   417504
# 674    253800                       Loft Suite @ Box House Hotel   417504
# 675    253803                   Loft Suite @ The Box House Hotel   417504
# 676    253806                   Loft Suite @ The Box House Hotel   417504
# 677    253811                   Loft Suite @ The Box House Hotel   417504
# 678    253815                   Loft Suite @ The Box House Hotel   417504
# 679    253828                Duplex w/ Terrace @ Box House Hotel   417504
# 680    253839                  Loft w/ Terrace @ Box House Hotel   417504
# 682    253846                               Superior @ Box House   417504
# 827    294227                   Loft Suite @ The Box House Hotel   417504
# 829    294242                   Loft Suite @ The Box House Hotel   417504
# 831    294259                       Loft Suite @ Box House Hotel   417504
# 832    294263                   Loft Suite @ The Box House Hotel   417504
# 833    294280                   Loft Suite @ The Box House Hotel   417504
# 836    294490                       Loft Suite @ Box House Hotel   417504
# 1098   464231                     Large Room w/ Private Entrance  1530310
# 1772   798008                Hancock Town House!-Stuyvesant Mews   758441
# 2564  1330056                Spacious Loft 5 min to Union Square   124357
# 3581  2138787                    HARLEM, NEW YORK WELCOMES YOU!!    68428
# 5243  3791244                       west village 1BR!best value!  2119276
# 5903  4303600  Luminous Modern Apt Share for Young Professionals  2822805
#
#                 host_name neighbourhood_group       neighbourhood  latitude  \
# 330   The Box House Hotel            Brooklyn          Greenpoint  40.73842
# 339   The Box House Hotel            Brooklyn          Greenpoint  40.73813
# 580          Keera (Jena)           Manhattan     Lower East Side  40.71892
# 669   The Box House Hotel            Brooklyn          Greenpoint  40.73641
# 670   The Box House Hotel            Brooklyn          Greenpoint  40.73794
# 674   The Box House Hotel            Brooklyn          Greenpoint  40.73730
# 675   The Box House Hotel            Brooklyn          Greenpoint  40.73708
# 676   The Box House Hotel            Brooklyn          Greenpoint  40.73652
# 677   The Box House Hotel            Brooklyn          Greenpoint  40.73693
# 678   The Box House Hotel            Brooklyn          Greenpoint  40.73784
# 679   The Box House Hotel            Brooklyn          Greenpoint  40.73674
# 680   The Box House Hotel            Brooklyn          Greenpoint  40.73783
# 682   The Box House Hotel            Brooklyn          Greenpoint  40.73731
# 827   The Box House Hotel            Brooklyn          Greenpoint  40.73683
# 829   The Box House Hotel            Brooklyn          Greenpoint  40.73890
# 831   The Box House Hotel            Brooklyn          Greenpoint  40.73806
# 832   The Box House Hotel            Brooklyn          Greenpoint  40.73661
# 833   The Box House Hotel            Brooklyn          Greenpoint  40.73857
# 836   The Box House Hotel            Brooklyn          Greenpoint  40.73857
# 1098              Jacques            Brooklyn  Bedford-Stuyvesant  40.68905
# 1772                 Fred            Brooklyn  Bedford-Stuyvesant  40.68561
# 2564                 Alex            Brooklyn        Williamsburg  40.71571
# 3581      Tye And Etienne           Manhattan  Washington Heights  40.83191
# 5243                 Host           Manhattan        West Village  40.73254
# 5903                Ollie            Brooklyn  Bedford-Stuyvesant  40.68531
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 330   -73.95312     Private room  249.0             3.0                2.0
# 339   -73.95394     Private room  179.0             3.0               13.0
# 580   -73.98401  Entire home/apt  199.0             1.0               14.0
# 669   -73.95330  Entire home/apt  199.0             3.0               24.0
# 670   -73.95254  Entire home/apt  199.0             3.0               59.0
# 674   -73.95323  Entire home/apt  199.0             3.0               24.0
# 675   -73.95271  Entire home/apt  199.0             3.0               23.0
# 676   -73.95236  Entire home/apt  199.0             3.0               43.0
# 677   -73.95316  Entire home/apt  199.0             3.0               30.0
# 678   -73.95324  Entire home/apt  199.0             3.0               39.0
# 679   -73.95247     Private room  349.0             3.0                8.0
# 680   -73.95259     Private room  249.0             3.0                3.0
# 682   -73.95450     Private room  179.0             3.0                4.0
# 827   -73.95430  Entire home/apt  199.0             3.0               43.0
# 829   -73.95395  Entire home/apt  199.0             3.0               75.0
# 831   -73.95462  Entire home/apt  199.0             3.0               73.0
# 832   -73.95479  Entire home/apt  199.0             3.0               89.0
# 833   -73.95435  Entire home/apt  199.0             3.0               23.0
# 836   -73.95299  Entire home/apt  199.0             3.0               54.0
# 1098  -73.95410     Private room   65.0             7.0                2.0
# 1772  -73.92029     Private room  165.0             1.0                0.0
# 2564  -73.95813     Private room   90.0             1.0              115.0
# 3581  -73.94110     Private room   62.0             2.0                4.0
# 5243  -74.00698  Entire home/apt  170.0            30.0               12.0
# 5903  -73.95185     Private room   60.0            30.0               44.0
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 330   2011-05-12               0.02                            28.0
# 339   2019-06-27               0.14                            28.0
# 580   2015-07-20               0.15                             2.0
# 669   2018-11-06               0.32                            28.0
# 670   2019-06-24               0.66                            28.0
# 674   2019-04-25               0.26                            28.0
# 675   2019-06-22               0.26                            28.0
# 676   2019-07-02               0.47                            28.0
# 677   2019-07-03               0.32                            28.0
# 678   2019-06-29               0.44                            28.0
# 679   2018-07-26               0.09                            28.0
# 680   2015-11-03               0.03                            28.0
# 682   2015-12-04               0.05                            28.0
# 827   2019-06-22               0.49                            28.0
# 829   2019-06-05               0.93                            28.0
# 831   2019-06-30               0.84                            28.0
# 832   2019-07-01               1.06                            28.0
# 833   2019-04-23               0.26                            28.0
# 836   2019-06-10               0.61                            28.0
# 1098  2012-05-29               0.02                             3.0
# 1772         NaN                NaN                             4.0
# 2564  2019-05-21               1.63                             3.0
# 3581  2019-04-01               0.19                             2.0
# 5243  2018-08-12               0.22                            39.0
# 5903  2019-05-19               0.78                             8.0
#
#       availability_365
# 330               60.0
# 339               81.0
# 580              158.0
# 669               84.0
# 670               60.0
# 674               60.0
# 675               60.0
# 676               60.0
# 677               56.0
# 678               84.0
# 679               58.0
# 680               60.0
# 682               81.0
# 827               84.0
# 829               84.0
# 831               56.0
# 832               62.0
# 833               81.0
# 836               60.0
# 1098               0.0
# 1772               0.0
# 2564             359.0
# 3581             336.0
# 5243             252.0
# 5903              99.0

# %%
# Let's check for any specific value.
airbnb_df.query('name == "✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿"')
# Out:
#          id                                name  host_id     host_name  \
# 579  219793  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
# 580  219818  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
#
#     neighbourhood_group    neighbourhood  latitude  longitude  \
# 579           Manhattan  Lower East Side  40.71813  -73.98416
# 580           Manhattan  Lower East Side  40.71892  -73.98401
#
#            room_type  price  minimum_nights  number_of_reviews last_review  \
# 579  Entire home/apt  199.0             1.0               29.0  2015-06-03
# 580  Entire home/apt  199.0             1.0               14.0  2015-07-20
#
#      reviews_per_month  calculated_host_listings_count  availability_365
# 579               0.31                             2.0             162.0
# 580               0.15                             2.0             158.0

# %% [markdown]
# In this now we can see that all the values are same except for last_review and reviews_per_month, which are not so important regarding duplicacy.

# %% [markdown]
# Now to drop the duplicated values we will sort out dataframe on the basis of latest entries, for which we need to have a timestamp in our dataset, in our dataset we can use the 'last_review' column as the timestamp for our dataset.

# %%
# Converting the 'last_review' column in a datetime format.
airbnb_df['last_review'] = pd.to_datetime(airbnb_df['last_review'])

# %%
# Now let us sort the data by the last_review column
airbnb_df = airbnb_df.sort_values(by='last_review', ascending=False).reset_index(drop=True)

# %% [markdown]
# As we can see there are few NA values in our dataframe in the date column let's fill these values with the latest dates we are having in our dataframe.

# %%
# Replacing NA Values
airbnb_df['last_review'].replace(np.nan,airbnb_df['last_review'].max(), inplace=True)

# Let's sort the values again
airbnb_df = airbnb_df.sort_values(by='last_review', ascending=False).reset_index(drop=True)
# Out:
# <ipython-input-31-3e053ca8e633>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df['last_review'].replace(np.nan,airbnb_df['last_review'].max(), inplace=True)

# %%
# Dropping duplicated values
airbnb_df = airbnb_df.drop_duplicates(subset=['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'], keep='first').reset_index(drop=True)

# Now the duplicated columns have been dropped, let's check the current shape of our data frame.
airbnb_df.shape # (48655, 14)

# Let's check if there are any duplicated values now
airbnb_df[airbnb_df.duplicated(subset=['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type'])] # No values

airbnb_df.query('name == "✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿"') # The latest value shows up
# Out:
#           id                                name  host_id     host_name  \
# 6865  219818  ✿✿✿ COUNTRY COTTAGE IN THE CITY✿✿✿  1138692  Keera (Jena)
#
#      neighbourhood_group    neighbourhood  latitude  longitude  \
# 6865           Manhattan  Lower East Side  40.71892  -73.98401
#
#             room_type  price  minimum_nights  number_of_reviews last_review  \
# 6865  Entire home/apt  199.0             1.0               14.0  2015-07-20
#
#       reviews_per_month  calculated_host_listings_count  availability_365
# 6865               0.15                             2.0             158.0

# %% [markdown]
# We have successfully dropped the duplicated values and now we only have latest data values.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_values = airbnb_df.isnull()
null_value_count = null_values.sum()

# Visualizing the missing values
null_value_count
# Out:
# id                                  0
# name                                7
# host_id                             0
# host_name                           5
# neighbourhood_group                 0
# neighbourhood                       0
# latitude                            0
# longitude                           0
# room_type                           1
# price                               1
# minimum_nights                      1
# number_of_reviews                   1
# last_review                         0
# reviews_per_month                 824
# calculated_host_listings_count      1
# availability_365                    1
# dtype: int64

# %% [markdown]
# As we can see we were having missing values in name and host_name columns, however as we are having their respective ids we will still be able to manage the data, however let us check for outliers.

# %%
# To check the outliers we need to check the columns which are having numerical data.
airbnb_df.describe()
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  7.366000e+03  7.366000e+03  7366.000000  7366.000000  7365.000000
# mean   2.450108e+06  7.946911e+06    40.729233   -73.950481   167.088255
# min    2.539000e+03  2.571000e+03    40.508680   -74.239860    10.000000
# 25%    8.270028e+05  1.631752e+06    40.688713   -73.984055    80.000000
# 50%    2.236745e+06  5.145120e+06    40.723135   -73.959395   120.000000
# 75%    4.036534e+06  1.205907e+07    40.763900   -73.943585   185.000000
# max    5.478741e+06  4.139808e+07    40.908040    -7.000000  9999.000000
# std    1.687955e+06  7.641046e+06     0.051814     0.781015   279.441266
#
#        minimum_nights  number_of_reviews                    last_review  \
# count     7365.000000        7365.000000                           7366
# mean         8.542566          50.846436  2018-06-19 15:15:06.109149952
# min          1.000000           0.000000            2011-03-28 00:00:00
# 25%          2.000000           4.000000            2017-10-27 06:00:00
# 50%          3.000000          18.000000            2019-05-18 00:00:00
# 75%          5.000000          68.000000            2019-06-25 00:00:00
# max       1250.000000         607.000000            2019-07-08 00:00:00
# std         29.808364          72.807274                            NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# count        6542.000000                     7365.000000       7365.000000
# mean            0.899862                        2.568364        133.299389
# min             0.010000                        1.000000          0.000000
# 25%             0.130000                        1.000000          0.000000
# 50%             0.420000                        1.000000         81.000000
# 75%             1.260000                        2.000000        273.000000
# max            13.450000                       96.000000        365.000000
# std             1.135513                        6.790762        138.464697

# %% [markdown]
# If we look into this data we can see that the price and the minimum_nights columns are the most concerning ones, in these 2 columns we need to find the outliers and drop them.

# %%
# As we see above the column_name 'calculated_host_listings_count' is quiet long
# Let's change it to 'listings'
airbnb_df.rename(columns={
    "calculated_host_listings_count": 'listings'
}, inplace=True)

# Lets check the price columns once
airbnb_df['price'].describe()

# As we can see the min price is 0 which is not likely to happen.
# According to the current website the price range starts from $25.
# In this case we will check for the prices which are below $25 and we will
# replace their values with 25 so that we can handle the outliers in price column.

airbnb_df['price'].replace(range(0, 25), 25, inplace=True) # replacing values
airbnb_df['price'].describe()
# Out:
# <ipython-input-35-5e31f3d75c36>:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df['price'].replace(range(0, 25), 25, inplace=True) # replacing values
# count    7365.000000
# mean      167.094773
# std       279.437838
# min        25.000000
# 25%        80.000000
# 50%       120.000000
# 75%       185.000000
# max      9999.000000
# Name: price, dtype: float64

# %% [markdown]
# As the few price values were less than $25, which is not likely to happen, we have converted those values into 25, so that we may handle the outliers more efficiently, as there was other crucial info present in those rows.

# %%
# Now let's check the minimum_nights column.
airbnb_df['minimum_nights'].describe()

# As the minimum value in this column is 1, we can work on only the upper limit.
# In this case if any value is more than 365 days, we will mark it as 365.

airbnb_df['minimum_nights'].replace(range(366, 1251), 365, inplace=True) # replacing values
airbnb_df['minimum_nights'].describe()
# Out:
# <ipython-input-36-6d516405d7f4>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df['minimum_nights'].replace(range(366, 1251), 365, inplace=True) # replacing values
# count    7365.000000
# mean        8.317176
# std        23.752655
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max       365.000000
# Name: minimum_nights, dtype: float64

# %% [markdown]
# Now we have modified the outliers, we can move ahead with our dataset ready to be wrangled for deriving insights.

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The Airbnb NYC 2019 Dataset contains:
#
# Rows: 48,895
# Columns: 16
# Data Overview:
# The dataset includes both numerical and categorical data:
#
# Numerical columns:
# 3 columns with float64 data type
# 7 columns with int64 data type
# Categorical columns:
# 6 columns with object data type
# The primary key of the dataset is the "id" column, which provides unique identifiers for the hotel names.
#
# Column List:
# ['id', 'name', 'host_id', 'host_name', 'neighbourhood_group', 'neighbourhood', 'latitude', 'longitude', 'room_type', 'price', 'minimum_nights', 'number_of_reviews', 'last_review', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']
#
# Duplicates:
# While there are no exact duplicate rows, the "name" column contains 998 duplicate entries. These duplicates likely represent the same hotel, with minor variations such as price differences, possibly adjusted over time based on market conditions.
#
# To address this, the dataset was sorted based on the latest entries using the "last_review" column as a timestamp. After performing these operations, duplicate entries were handled successfully.
#
# Handling Missing Values:
# The following columns contained a significant number of null values:
#
# "last_review": 10,052 missing values
# "reviews_per_month": 10,052 missing values
# For the "last_review" column, missing values were replaced with the latest date in the dataset to ensure the timestamp remained efficient.
#
# Additionally, some "name" and "host_name" entries were missing:
#
# "name": 16 missing values
# "host_name": 21 missing values
# Final Steps:
# After handling duplicates and missing values, the dataset has been successfully formatted and is ready for data wrangling.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Looking on our data once
airbnb_df.head()
# Out:
#         id                                             name   host_id  \
# 0   639199  Beautiful 4BR/4BA Home, Staten Island, NY City.   1483081
# 1  2243984                    Superbowl in the West Village  11461854
# 2  2257080              SUPERBOWLSUNDAY! 3BLOCK FROM TIMESQ   3312524
# 3  2256519              Spacious 1BR Chelsea Apt. for SB 48  11523254
# 4  2254469              Private Studio Apt, Luxury Building  11512908
#
#   host_name neighbourhood_group    neighbourhood  latitude  longitude  \
# 0    Marina       Staten Island      Tottenville  40.50868  -74.23986
# 1    Lauren           Manhattan     West Village  40.73295  -74.00755
# 2    Athena           Manhattan   Hell's Kitchen  40.75361  -73.99501
# 3  Nicholas           Manhattan          Chelsea  40.74344  -73.99826
# 4  Augustus           Manhattan  Upper East Side  40.77320  -73.95082
#
#          room_type   price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt   299.0             3.0               59.0  2019-07-08
# 1  Entire home/apt  1500.0             1.0                0.0  2019-07-08
# 2  Entire home/apt   350.0             1.0                0.0  2019-07-08
# 3  Entire home/apt   750.0             2.0                0.0  2019-07-08
# 4  Entire home/apt   400.0             2.0                0.0  2019-07-08
#
#    reviews_per_month  listings  availability_365
# 0               0.82       1.0             245.0
# 1                NaN       1.0               0.0
# 2                NaN       1.0               0.0
# 3                NaN       1.0               0.0
# 4                NaN       1.0               0.0

# %%
# Dataset Columns
df_columns = airbnb_df.columns
df_columns # All the columns of our cleaned data.
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'listings', 'availability_365'],
#       dtype='object')

# %% [markdown]
# There are basically 3 types of variables according to their roles:-
#
# - Numerical Variables: These variables represent quantitative data and can be further categorized into:-
#
#   - Continuous Variables: These variables can take any value within the given number of range.
#   - Discrete Variables: These variables are having a specific value and are related to a specific identity.
#
# - Categorical Variables: These variables represent qualitative data and can be further categorized into:-
#   - Nominal Variables: These variables are random and they do not follow any order or ranking.
#   - Ordinal Variables: These variables are according to an order they can be ranked as well.
#
# - Time Variables: These variables are basically date and time variables having a timestamp.

# %%
# Dataset Describe
df_describe = airbnb_df.describe()
df_describe # These are all the numerical variables in our dataset.
# Out:
#                  id       host_id     latitude    longitude        price  \
# count  7.366000e+03  7.366000e+03  7366.000000  7366.000000  7365.000000
# mean   2.450108e+06  7.946911e+06    40.729233   -73.950481   167.094773
# min    2.539000e+03  2.571000e+03    40.508680   -74.239860    25.000000
# 25%    8.270028e+05  1.631752e+06    40.688713   -73.984055    80.000000
# 50%    2.236745e+06  5.145120e+06    40.723135   -73.959395   120.000000
# 75%    4.036534e+06  1.205907e+07    40.763900   -73.943585   185.000000
# max    5.478741e+06  4.139808e+07    40.908040    -7.000000  9999.000000
# std    1.687955e+06  7.641046e+06     0.051814     0.781015   279.437838
#
#        minimum_nights  number_of_reviews                    last_review  \
# count     7365.000000        7365.000000                           7366
# mean         8.317176          50.846436  2018-06-19 15:15:06.109149952
# min          1.000000           0.000000            2011-03-28 00:00:00
# 25%          2.000000           4.000000            2017-10-27 06:00:00
# 50%          3.000000          18.000000            2019-05-18 00:00:00
# 75%          5.000000          68.000000            2019-06-25 00:00:00
# max        365.000000         607.000000            2019-07-08 00:00:00
# std         23.752655          72.807274                            NaN
#
#        reviews_per_month     listings  availability_365
# count        6542.000000  7365.000000       7365.000000
# mean            0.899862     2.568364        133.299389
# min             0.010000     1.000000          0.000000
# 25%             0.130000     1.000000          0.000000
# 50%             0.420000     1.000000         81.000000
# 75%             1.260000     2.000000        273.000000
# max            13.450000    96.000000        365.000000
# std             1.135513     6.790762        138.464697

# %% [markdown]
# ### Variables Description

# %% [markdown]
# As we can see that we are having various outputs that can be studied so as to attain certain measures and draw conclusions on the basis of the data.
# For example: we have a wide range of prices available, however the average price range prefered by the customers are around 150, which gives us an idea on the budget of the guests and their preference.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
def unique_value(df):
  for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for '{column}': {unique_values}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# As our Data cleaning, Data transformation, and Handling outliers has been completed, now we will be working on "Feature Engineering".

# %%
# Let's create a new column with the price range distribution.
# We will use it while working with the price column.
start = 0
end = 10000
breakpoints = np.linspace(start, end, num=101)
breakpoints = breakpoints.astype(int)
def price_range(amt):
    bp = breakpoints
    for i in range(len(breakpoints)-1):
        if bp[i] <= amt <= bp[i+1]:
            return f"{bp[i]} - {bp[i+1]}"


airbnb_df['price_range'] = airbnb_df['price'].apply(lambda amt: price_range(amt))
airbnb_df['price_range']
# Out:
# 0         200 - 300
# 1       1400 - 1500
# 2         300 - 400
# 3         700 - 800
# 4         300 - 400
#            ...
# 7361        0 - 100
# 7362      100 - 200
# 7363        0 - 100
# 7364      200 - 300
# 7365        0 - 100
# Name: price_range, Length: 7366, dtype: object

# %% [markdown]
# Creating this price range column can provide us these benefits:-
#
# - Data Summarization: As this will provide an effective summary of the price distribution in our dataset.
# - Visualization: on a price range instead of individual price column is much more effective.
# - Segmentation and Analysis: As it will divide the prices into different segments it would be really easy to compare the prices into different segments or ranges.
# - Decision Making: It can help us in various decisions making, into different scenarios, like we can use this info to provide recommendations to the customers according to their budget and rerquirements.
# - Communicating Insights: Price range can easily communicate the budget and preferences of our customers and it can also tell us where does the majority of our cutomers lies, according to their purchasing power.

# %%
# Let's take a look at our dataset once.
airbnb_df.head()

# As we can see our dataset is sorted according to the last review, let us sort our dataset according to the price.
airbnb_df.sort_values(by='price', ascending=False, inplace=True)

# Let's take a look at our price sorted dataset once.
airbnb_df.head()
# Out:
#            id                                 name   host_id    host_name  \
# 7080  4737930                   Spanish Harlem Apt   1235070        Olson
# 6094  2953058                        Film Location   1177497      Jessica
# 44    2271504     SUPER BOWL Brooklyn Duplex Apt!!  11598359     Jonathan
# 7024  2110145   UWS 1BR w/backyard + block from CP   2151325  Jay And Liz
# 15    2243699  SuperBowl Penthouse Loft 3,000 sqft   1483320         Omri
#
#      neighbourhood_group    neighbourhood  latitude  longitude  \
# 7080           Manhattan      East Harlem  40.79264  -73.93898
# 6094            Brooklyn     Clinton Hill  40.69137  -73.96723
# 44              Brooklyn     Clinton Hill  40.68766  -73.96439
# 7024           Manhattan  Upper West Side  40.77782  -73.97848
# 15             Manhattan     Little Italy  40.71895  -73.99793
#
#             room_type   price  minimum_nights  number_of_reviews last_review  \
# 7080  Entire home/apt  9999.0             5.0                1.0  2015-01-02
# 6094  Entire home/apt  8000.0             1.0                1.0  2016-09-15
# 44    Entire home/apt  6500.0             1.0                0.0  2019-07-08
# 7024  Entire home/apt  6000.0            14.0               17.0  2015-02-17
# 15    Entire home/apt  5250.0             1.0                0.0  2019-07-08
#
#       reviews_per_month  listings  availability_365   price_range
# 7080               0.02       1.0               0.0  9900 - 10000
# 6094               0.03      11.0             365.0   7900 - 8000
# 44                  NaN       1.0               0.0   6400 - 6500
# 7024               0.27       1.0             359.0   5900 - 6000
# 15                  NaN       1.0               0.0   5200 - 5300

# %%
# Let us check our columns and filter those columns that will work as our features.
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'listings', 'availability_365', 'price_range'],
#       dtype='object')

# %% [markdown]
# We can consider these columns to be our features so that we can work with these:-
#
# - id
# - host_id
# - neighbourhood_group
# - neighbourhood
# - room_type
# - price
# - price_range
# - minimum_nights
# - number_of_reviews
# - reviews_per_month
# - listings
# - availability_365

# %%
# Let filter the dataframe with only the required columns.
feature_df = airbnb_df[['id', 'name', 'host_id', 'neighbourhood_group',
       'neighbourhood', 'room_type', 'price', 'minimum_nights',
       'number_of_reviews', 'reviews_per_month', 'listings',
       'availability_365', 'price_range']]

feature_df = feature_df.reset_index(drop=True)
feature_df.head()
# Out:
#         id                                 name   host_id neighbourhood_group  \
# 0  4737930                   Spanish Harlem Apt   1235070           Manhattan
# 1  2953058                        Film Location   1177497            Brooklyn
# 2  2271504     SUPER BOWL Brooklyn Duplex Apt!!  11598359            Brooklyn
# 3  2110145   UWS 1BR w/backyard + block from CP   2151325           Manhattan
# 4  2243699  SuperBowl Penthouse Loft 3,000 sqft   1483320           Manhattan
#
#      neighbourhood        room_type   price  minimum_nights  \
# 0      East Harlem  Entire home/apt  9999.0             5.0
# 1     Clinton Hill  Entire home/apt  8000.0             1.0
# 2     Clinton Hill  Entire home/apt  6500.0             1.0
# 3  Upper West Side  Entire home/apt  6000.0            14.0
# 4     Little Italy  Entire home/apt  5250.0             1.0
#
#    number_of_reviews  reviews_per_month  listings  availability_365  \
# 0                1.0               0.02       1.0               0.0
# 1                1.0               0.03      11.0             365.0
# 2                0.0                NaN       1.0               0.0
# 3               17.0               0.27       1.0             359.0
# 4                0.0                NaN       1.0               0.0
#
#     price_range
# 0  9900 - 10000
# 1   7900 - 8000
# 2   6400 - 6500
# 3   5900 - 6000
# 4   5200 - 5300

# %%
feature_df.head()
# Out:
#         id                                 name   host_id neighbourhood_group  \
# 0  4737930                   Spanish Harlem Apt   1235070           Manhattan
# 1  2953058                        Film Location   1177497            Brooklyn
# 2  2271504     SUPER BOWL Brooklyn Duplex Apt!!  11598359            Brooklyn
# 3  2110145   UWS 1BR w/backyard + block from CP   2151325           Manhattan
# 4  2243699  SuperBowl Penthouse Loft 3,000 sqft   1483320           Manhattan
#
#      neighbourhood        room_type   price  minimum_nights  \
# 0      East Harlem  Entire home/apt  9999.0             5.0
# 1     Clinton Hill  Entire home/apt  8000.0             1.0
# 2     Clinton Hill  Entire home/apt  6500.0             1.0
# 3  Upper West Side  Entire home/apt  6000.0            14.0
# 4     Little Italy  Entire home/apt  5250.0             1.0
#
#    number_of_reviews  reviews_per_month  listings  availability_365  \
# 0                1.0               0.02       1.0               0.0
# 1                1.0               0.03      11.0             365.0
# 2                0.0                NaN       1.0               0.0
# 3               17.0               0.27       1.0             359.0
# 4                0.0                NaN       1.0               0.0
#
#     price_range
# 0  9900 - 10000
# 1   7900 - 8000
# 2   6400 - 6500
# 3   5900 - 6000
# 4   5200 - 5300

# %% [markdown]
# As we can see we are having few groups in our datasets, let us check what all insights we can derive from them, by seeking information according to the groups.

# %%
# Let's check the top performing Host as per the total listing count
host_groups = feature_df.groupby('name')
hosts = []
no_of_listings = []
host_prices = []
for host, data in host_groups:
  hosts.append(host)
  no_of_listings.append(data['listings'].sum())
  host_prices.append(data['price'].mean())

host_df = pd.DataFrame({
    'Host Name': hosts,
    'Total Listings': no_of_listings,
    'Price': host_prices
})
host_df = host_df.sort_values(by='Total Listings', ascending=False).reset_index(drop=True)
host_df = host_df.drop_duplicates(subset='Total Listings').reset_index(drop=True)
top_10_hosts = host_df.head(10)

host_df['Revenue'] = (host_df['Total Listings'])*(host_df['Price'])
top_host_revenue = host_df.sort_values(by='Revenue', ascending=False).reset_index(drop=True)
top_host_revenue.head(10)
# Out:
#                                            Host Name  Total Listings   Price  \
# 0                     5136-Doorman 2 bedroom 3 beds!            96.0   250.0
# 1                  2 BR w/ Terrace @ Box House Hotel            28.0   599.0
# 2                Luxury 1Bed with Central Park Views            11.0  1000.0
# 3                 Stunning 2BR Penthouse w/City View            52.0   199.0
# 4                New BLDG~Balcony~W/D~Prime location            39.0   170.0
# 5                 GORGEOUS Newly-Renovated 2-BR Flat            29.0   142.0
# 6   *PIZZAZZ* Fantastic Studio Apartment-Upper East!            34.0   115.0
# 7                         Super Quiet, Private Patio            21.0   130.0
# 8                  Large Room in Penthouse Apartment            26.0    95.0
# 9  DOMINIQUE'S  NYC  cosy,2 bedrm crashPad*Stay h...            13.0   155.0
#
#    Revenue
# 0  24000.0
# 1  16772.0
# 2  11000.0
# 3  10348.0
# 4   6630.0
# 5   4118.0
# 6   3910.0
# 7   2730.0
# 8   2470.0
# 9   2015.0

# %%
# First let's check how many neighbourhood_groups are there.
feature_df['neighbourhood_group'].unique() # There are 5 different groups.

# ['Brooklyn', 'Queens', 'Manhattan', 'Staten Island', 'Bronx']
#  let's group our dataset according to the neighbourhood groups.

n_groups = feature_df.groupby('neighbourhood_group')

# Let's check which group is most prefered as per the listings, and no. of reviews.
groups = [] # To save the groups
listings = []
reviews = []
max_price = []
min_price = []
for group, data in n_groups:
  groups.append(group)
  listings.append(data['listings'].sum())
  reviews.append(data['number_of_reviews'].sum())
  max_price.append(data['price'].max())
  min_price.append(data['price'].min())

group_feat_df = pd.DataFrame({
    'Group': groups,
    'Listing Count': listings,
    'No._of_reviews': reviews,
    'Min Price': min_price,
    'Max Price': max_price
})

group_feat_df
# Here we can see that Manhattan group is the most prefered group as per the listings.
# However the most reviews are given to the Brooklyn group.

# Now let's divide our dataset as per the room types, and create their groups.
# First let's check how room_types are there.

feature_df['room_type'].unique() # There are 3 room types.

# ['Entire home/apt', 'Private room', 'Shared room']
#  let's group our dataset according to the room types.

room_groups = feature_df.groupby('room_type')
rooms = []
room_listings = []
room_reviews = []
max_room_price = []
min_room_price = []
for room_type, room_data in room_groups:
    rooms.append(room_type)
    room_listings.append(room_data['listings'].sum())
    max_room_price.append(room_data['price'].max())
    min_room_price.append(room_data['price'].min())

room_feat_df = pd.DataFrame({
    'Group': rooms,
    'Listing Count': room_listings,
    'Min Price': min_room_price,
    'Max Price': max_room_price
})

room_feat_df
# Here we can see the most prefered room type is the Entire home/apt.
# The most reviews are also given to the Entire home/apt.
# Shared rooms are the least prefered.
# Out:
#              Group  Listing Count  Min Price  Max Price
# 0  Entire home/apt        12852.0       25.0     9999.0
# 1     Private room         5902.0       25.0     5000.0
# 2      Shared room          162.0       25.0     1000.0

# %%
# Now let us check how many different neighbourhoods are there in total.
feature_df['neighbourhood'].count() # There are 48655 neighbourhoods

# Now let us check what are the top 10 most prefered neighbourhoods.
# Also, let's check their average pricing and average price range.
area_groups = feature_df.groupby('neighbourhood')
areas = []
listing_count = []
avg_price = []
for area, n_data in area_groups:
  areas.append(area)
  listing_count.append(n_data['listings'].sum())
  avg_price.append(round(n_data['price'].mean(), 2))

area_feat_df = pd.DataFrame({
    'Area': areas,
    'Listing Count': listing_count,
    'Average Price': avg_price,
})

area_feat_df = area_feat_df.sort_values(by='Listing Count', ascending=False).reset_index(drop=True)
area_feat_df.head(10)
# Out:
#                  Area  Listing Count  Average Price
# 0          Greenpoint         2705.0         143.12
# 1     Upper East Side         1455.0         188.09
# 2     Upper West Side         1381.0         251.77
# 3      Hell's Kitchen         1251.0         189.64
# 4  Bedford-Stuyvesant         1124.0         127.06
# 5        Williamsburg          936.0         148.87
# 6              Harlem          769.0         121.53
# 7        East Village          642.0         204.75
# 8            Kips Bay          526.0         247.00
# 9             Chelsea          497.0         229.82

# %% [markdown]
# In the above manipulations we have created and worked with few groups that were there in our dataset, based upon which we were able to derive few insights.

# %%
# Let us now work with relationships.
# Relationship: Price vs. Room Type
# Checking the distribution of prices for different room types.
# "room_groups" is our grouped dataframe we will be using this.

avg_room_price = []
for room, data in room_groups:
  avg_room_price.append(data['price'].mean())

room_vs_price = pd.DataFrame({
    'Room Type': rooms,
    'Avg_Price': avg_room_price
})

room_vs_price

# As we can see here the Entire home/apt is having the highest pricing.
# Out:
#          Room Type   Avg_Price
# 0  Entire home/apt  216.719673
# 1     Private room   93.453021
# 2      Shared room   90.970000

# %%
# Relationship: Reviews per Month vs. Room Type
# Comparing the distribution of reviews per month for different room types.

total_reviews = []
for room, data in room_groups:
  total_reviews.append(data['reviews_per_month'].sum())

room_vs_reviews = pd.DataFrame({
    'Room Type': rooms,
    'Reviews': total_reviews
})

room_vs_reviews
# As we can see here the Entire home/apt is having the highest no. of reviews per month.
# Out:
#          Room Type  Reviews
# 0  Entire home/apt  3169.86
# 1     Private room  2637.59
# 2      Shared room    79.45

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# This dataset contained a well-distributed wealth of information, which was a significant advantage for our study. Since this dataset pertains to Airbnb, the locations played a critical role in shaping these values, and the information was appropriately distributed across various locations and their respective areas.
#
# We performed several data manipulations to extract insights that would be valuable for stakeholders in making informed business decisions. Additionally, these insights would help hosts understand customer preferences, aligning with the goals we outlined in our agenda.
#
# ### Data Manipulation Process
#
# We divided the entire process into two primary parts based on features and relationships to systematically draw insights:
#
# #### Key Manipulations Performed:
#
# 1. **Created a New Price Range Column**:
#    - This column helped categorize price distribution and provided a simplified perspective on customer budget trends. Efforts were made to keep this categorization as precise as possible.
#
# 2. **Sorted the Dataset by Price**:
#    - Since the data was unsorted and lacked significance in its original form, we organized it based on pricing, with the most expensive listings appearing at the top.
#
# 3. **Filtered the Data**:
#    - To make the dataset easier to analyze and less cluttered, we focused only on the columns essential for data analysis and feature engineering.
#
# 4. **Categorized Data into Groups**:
#    - Data was divided into categorical groups to derive structured insights. This provided more specific information for each group, helping us understand customer behavior more clearly. The groups created included:
#      - **Neighbourhood Groups**: Identified the most preferred neighbourhoods among all options.
#      - **Room Type Groups**: Determined which room types were most popular among customers.
#      - **Neighbourhood Area Groups**: Highlighted the most preferred areas within each neighbourhood.
#
# #### Relationships Explored:
#
# We also examined relationships between various attributes to provide stakeholders with actionable insights. Key relationships studied included:
#
# 1. **Price vs. Room Type**:
#    - Analyzed the price distribution for different room types.
#    - Identified which room type had the highest price range.
#
# 2. **Reviews per Month vs. Room Type**:
#    - Compared review distribution for different room types.
#    - Assessed customer engagement and satisfaction levels based on room types.
#
# 3. **Price vs. Neighbourhood**:
#    - Compared price distributions across neighbourhoods.
#    - Identified neighbourhoods with higher or lower average prices and analyzed price variations by area.
#
# ### Conclusion
#
# These manipulations and analyses were conducted to derive actionable insights that can contribute to the growth of our business, enhance host performance, and ultimately improve the travel experience for our customers. The specific insights are highlighted alongside visualizations for better clarity and understanding.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Let's visualize the most prefered neighbourhood group with a bar chart

group_feat_df # As we have already created a dataframe for the groups

plt.figure(figsize=(10,5))
# plt.plot(groups,listings, color='black', marker = "o", markerfacecolor = 'blue', markeredgecolor='blue',linestyle='-')
colors = ['red', 'blue', 'green', 'orange', 'purple'] # To make each bar with a different color
sns.barplot(x="Group", y='Listing Count', data=group_feat_df, hue='Group', palette=colors, legend=False)
plt.xlabel('Groups')
plt.ylabel('Listing Counts')
plt.title('Most prefered neighbourhood')
for x, y in zip(range(len(groups)), listings):
    plt.text(x, y, f'{y}', ha='center', va='bottom') # To annotate each bar with the exact value

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To determine which group has the highest preference, it was clear that we needed to evaluate the values for each group and compare them. A bar chart was the most suitable choice for this purpose, as it effectively visualizes the comparison across all groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can clearly see that Manhattan is the most prefered group among all and it is outperforming all the other groups with a huge difference, Brooklyn is the 2nd prefernce of our customers after Manhattan.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely, the gained insights will have a positive business impact by helping us understand customer preferences. This allows us to focus on the most in-demand areas and align our offerings to meet customer needs, ensuring their satisfaction. In this case, knowing that Manhattan is the most preferred group, we can strategically target customers by highlighting the availability in that area.
#
# Regarding negative growth, it is evident in other neighborhood groups due to lower demand. To address this, we need to investigate why Manhattan is the most preferred and identify the factors contributing to the low demand in other areas. By focusing on these reasons and understanding the differences, we can uncover the root causes and work towards improving demand in those neighborhoods.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Let's visualize the most prefered room type using a pie chart

room_feat_df # Our grouped df created earlier

# Plotting the data into a pie chart
plt.pie(room_feat_df['Listing Count'], labels=room_feat_df['Group'], autopct="%1i%%", explode=(0.1, 0, 0.1), shadow=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since there were only three types of rooms, using a pie chart was the ideal choice. It made it easy to visualize the distribution of listings and clearly compare the proportions of each room type. Additionally, the percentage differences were effectively highlighted, providing a broader perspective on the data and its outcomes.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is evident that the "Entire Home/Apt" room type is the most preferred, indicating that people prioritize their privacy and prefer staying independently without any interference. On the other hand, shared rooms, being the least preferred, are typically chosen by students from outside the area who seek affordable accommodation. This insight can be effectively leveraged for more targeted and specific marketing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By understanding the preferences of the majority of our customers, we can allocate our advertising budget more effectively, reducing unnecessary expenses. Additionally, identifying the specific customer segments that prefer other room types enables us to tailor our marketing strategies to meet their needs. This approach not only expands our consumer market but also helps drive demand in low-demand sectors, potentially serving as a strategic advantage for us.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Now let's check which price range has the most number of listings, it would give us an idea for the most prefered price range of our customers.
# Let's plot the top 10 most prefered price range on chart.
prefered_range = airbnb_df['price_range'].value_counts().head(10)
plt.figure(figsize=(10,5))

prefered_range_sorted = prefered_range.sort_index()
plt.scatter(prefered_range.index, prefered_range, color='blue', marker='o')
plt.plot(prefered_range_sorted.index, prefered_range_sorted, color='black', linestyle='-', linewidth=2, label='Line Connecting Dots')

for x, y in zip(prefered_range_sorted.index, prefered_range_sorted): # To annotate each plotted value
    plt.text(x, y, f'{y}', ha='center', va='bottom')
plt.title("Top 10 Prefered Price Range")
plt.xlabel("Price Range")
plt.ylabel("Listings")
plt.grid(color='black')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The plot chart provides a graphical representation of customer preferences across different price ranges. It clearly illustrates how preferences decline as the price range increases.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart clearly highlights the budget preferences of our customers, showing that the most preferred price range is 0-100. However, it’s important to note that 0 values have already been excluded. This insight provides a better understanding of our customers’ spending power, which can guide us in setting more targeted and competitive prices

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, Customers appreciate personalized interfaces and tailored options and by focusing on providing them with choices specifically aligned with their preferences, we can enhance their experience.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
# Let us now visualize the average price division with room types.

data = {
    'Room Type': room_vs_price['Room Type'],
    'Avg_Price': room_vs_price['Avg_Price'],
    'Listings': ((room_feat_df['Listing Count']/room_feat_df['Listing Count'].sum())*100)
}

# Creating a DataFrame
df = pd.DataFrame(data)

df_melted = pd.melt(df, id_vars='Room Type', var_name='Attribute', value_name='Value')
# Creating a strip plot
sns.barplot(x='Room Type', y='Value', data=df_melted, hue="Attribute", palette=['blue', 'grey'], legend=True)

# Applying annotations on the values
for p in plt.gca().patches:
    plt.gca().annotate('{:.1f}'.format(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                       ha='center', va='center', fontsize=10, color='black', xytext=(0, 5),
                       textcoords='offset points')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  We only have three types, using a bar chart was a better choice for visualizing the divisions of average prices and the percentage distribution of listings across these categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is evident that there is a direct relationship between average pricing and listing counts. The "Entire Home/Apt" room type has both the highest pricing and the largest share of listings. This insight can be highly valuable for making informed decisions, such as setting appropriate pricing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, as we can see what percentage is ready to pay which amount for their preferences we will be able to make better pricing strategies which will definitely assist us in the growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
# Let's visualize the relationship between listing price and the number of reviews received.
# As we are having huge number of rows for this we will be taking only top 10 price ranges.
# For the listing prices we will take price_range

sorted_range = feature_df.sort_values(by='price_range', ascending=False)
sorted_range = sorted_range.groupby('price_range')
range_group = []
review_count = []
for range, data in sorted_range:
  range_group.append(range)
  review_count.append(data['number_of_reviews'].sum())

range_df = pd.DataFrame({
    'Range': range_group,
    'Review Count': review_count
})
plt.figure(figsize=(15, 5))
sns.scatterplot(x='Range', y='Review Count', data=range_df.head(10), color='blue', legend=False, marker='o')
plt.plot(range_df['Range'].head(10), range_df['Review Count'].head(10), color='grey', linestyle='--', linewidth=2, label='Line Connecting Dots')
plt.title("Price vs Reviews of top 10 most prefered price range")
for x, y in zip(range_df['Range'].head(10), range_df['Review Count'].head(10)):
  plt.text(x, y, f'{y}', ha='center', va='bottom')

# %%
# Let us also check for the least 10 prefered price ranges
plt.figure(figsize=(15, 5))
sns.scatterplot(x='Range', y='Review Count', data=range_df.tail(10), color='blue', legend=False, marker='o')
plt.plot(range_df['Range'].tail(10), range_df['Review Count'].tail(10), color='grey', linestyle='--', linewidth=2, label='Line Connecting Dots')
plt.title("Price vs Reviews of bottom least 10 prefered price range")
for x, y in zip(range_df['Range'].tail(10), range_df['Review Count'].tail(10)):
  plt.text(x, y, f'{y}', ha='center', va='bottom')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# As the difference between the no. of reviews in the price range is very huge, using a plot chart is quiet handy so that the pointers can be seen clearly with respect to their values and also their differences.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see the price range and the no. of reviews are having inverse relationship, it cleary states that the budget of our majortiy customer base lies between the range 0 - 200.
#
# We can also see that there are few preferences in the higher budget section as well where there is a competetion in the prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This indicates that we can create more targeted and specific pricing policies, allowing us to expand our customer base by offering prices that align with their budgets.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# Let us know the price range having the highest listings so as to get more specific idea on price preference.


sorted_range # Sorted Price Range grouped
range_group # List of all the price range groups
range_listing_count = []

for range, data in sorted_range:
  range_listing_count.append(data['listings'].sum())


range_list_df = pd.DataFrame({
    'Range': range_group,
    'Listing Count': range_listing_count
})

range_list_df = range_list_df.sort_values(by='Listing Count', ascending=False).reset_index(drop=True)

# We will be taking on the top 5 prefered ranges.
plt.pie(range_list_df['Listing Count'].head(), labels=range_list_df['Range'].head(), autopct="%1i%%", explode=(0.1, 0.1, 0.1, 0, 0), shadow=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is an effective tool for visualizing distributions and preferences, making it easier to observe the division of listings across different price ranges.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As the chart says :
# The top 3 price ranges that have the most listings are as follows :-
# - 200-300: 33%
# - 100-200: 28%
# - 0-100: 22%

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# We can see the number of listings are closely divided among these sectors and this can be a great was to keep a track of all the hostels that are within this price range and create recommendations according to their prefered neighbourhoods.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
# As now we are having the price ranges with the most listings let us check the neighbourhoods with the most listings.

areas = []
area_listing = []
area_group = feature_df.groupby('neighbourhood')
for area, data in area_group:
    areas.append(area)
    area_listing.append(data['listings'].sum())

area_data_df = pd.DataFrame({
    "Area": areas,
    "Values": area_listing
})

area_data_df = area_data_df.sort_values(by='Values', ascending=False).reset_index(drop=True)
area_data_df
plt.figure(figsize=(17,5))
# plt.plot(groups,listings, color='black', marker = "o", markerfacecolor = 'blue', markeredgecolor='blue',linestyle='-')
colors = ['red', 'blue', 'green', 'orange', 'purple']
sns.barplot(x="Area", y='Values', data=area_data_df.head(10), hue="Area", palette=colors, legend=False)
plt.title('Top 10 prefered neighbourhood areas')
plt.xlabel('Area')
plt.ylabel('Listing Counts')
for x, y in zip(area_data_df['Area'].head(10), area_data_df['Values'].head(10)):
    plt.text(x, y, f'{y}', ha='center', va='bottom')
# Out:
# <ipython-input-58-30fc849892e1>:21: UserWarning:
# The palette list has fewer values (5) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(x="Area", y='Values', data=area_data_df.head(10), hue="Area", palette=colors, legend=False)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The bar chart clearly highlights the differences between neighborhoods and the gaps in listing counts. It effectively showcases the top ten neighborhoods with the highest number of listings.italicized text

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar chart shows that the 'Financial District' has the highest number of listings and a significant gap compared to other neighborhoods on the list. This clearly indicates that the Financial District is the most preferred neighborhood among our customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,this insight highlights areas with significant business potential, allowing us to create more opportunities and implement targeted advertising strategies to maximize impact and growth.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 9 visualization code
# Reviews vs Review per month
sns.scatterplot(x='number_of_reviews', y='reviews_per_month', data=feature_df)
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='reviews_per_month'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In this case, using a scatter plot effectively shows the frequency, as it reveals that the review traffic is not widely scattered but rather concentrated in specific areas.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is evident that there is an outlier in the data. However, the relationship between the total number of reviews and reviews per month appears to be quite direct. This suggests that customers are generally satisfied with their experiences, as higher review counts indicate positive engagement. Additionally, it reflects that hosts are successfully reaching and connecting with the consumer market.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes as we can seek out the difference from the given reviews and make specific recommendations to our hosts about what changes can be done by them in order to increase their reach to the customers. This can be one of our premium services that can widely help our hosts.

# %% [markdown]
# #### Chart - 9 - Pair Plot

# %%
# Chart - 9 visualization code
# Let's create a pairplot to know the relationship between our few variables.

pair_df = feature_df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'listings', 'availability_365', 'price_range']]
sns.pairplot(pair_df)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here we can easily see the distribution of our numerical variables, it will also give us an overview of our dataset and the relationships between our variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Yes, it is clear that the vast majority of our dataset falls within the price range of 0-2500.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This insight provides an overview of our dataset, giving us a clear understanding of the numerical value ranges we need to focus on. It helps us identify the scope and direction for our efforts, making it easier to prioritize and strategize effectively.

# %% [markdown]
# #### Chart - 10 - Correlation Heatmap

# %%
# Chart - 10 visualization code
feature_df.describe()

# using corr() function to check the correlation between numeric columns.
corr_df = feature_df[['price', 'minimum_nights', 'number_of_reviews',
             'reviews_per_month', 'listings', 'availability_365']].corr()

# Visualizing correlation using seaborn heatmap, using annotations.
sns.heatmap(corr_df, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the correlation between numeric columns, a heatmap is an excellent choice. It visually represents the strength of each correlation using a gradient of colors, from lighter to darker shades, depending on the correlation depth. Additionally, it provides a comprehensive, at-a-glance overview of the relationships within the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart enabled us to identify pairs of variables with strong positive or negative correlations.
#
# It also provided insights into which variables are most closely related to one another.Additionally, it highlighted potential multicollinearity issues (high correlations among independent variables), which is crucial to consider when performing regression analysis.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, utilizing these factors will provide valuable assistance in building predictive models. This information is not only crucial for understanding the current state of our business but also for identifying potential opportunities in various areas, helping us strategize more effectively.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To address the business objective, we have thoroughly analyzed the dataset and drawn several key insights. Here are the recommendations based on the findings:
#
# - **Pricing Strategy**: The most preferred price range is 0–300, indicating a clear direction for setting competitive pricing. Targeting this range can align offerings with customer expectations.
#
# - **Room Type Preference**: "Entire home/apt" is the most preferred room type, highlighting customers' emphasis on privacy and safety. Developing policies and features that reinforce these aspects can build trust, enhance customer satisfaction, and strengthen goodwill.
#
# - **Location Insights**: The Financial District in the Manhattan Neighborhood Group is the most preferred area. Recommendations tailored to this neighborhood's pricing and area preferences can attract more customers. Additionally, by identifying the features that have contributed to its popularity, similar improvements can be implemented in other neighborhoods to drive growth across different areas.
#
# - **Customer Reviews**: The Financial District also has the highest number of reviews. By analyzing the factors contributing to customer satisfaction in this area, actionable strategies can be developed to replicate these successes in less popular neighborhoods, expanding business potential.
#
# - **Additional Data Recommendation**: Including a column for customers' occupations in the dataset would allow for the segmentation of customers by professional background. This insight would help identify accommodation preferences for different occupational groups, enabling more targeted marketing and personalized offerings.
#
# - **Budget Insights**: The dataset provides a clear understanding of the majority of customers' budgets, enabling better alignment of pricing strategies. Additionally, it reveals the ratio of preferred pricing, which can guide resource allocation and advertising efforts.
#
# - **Consumer Segmentation**: The dataset highlights where the majority of business originates and which customer groups contribute most significantly. By improving offerings in these areas and simultaneously focusing on less popular sectors, the business can expand its reach and diversify its customer base.
#
# These insights and recommendations can help optimize pricing, enhance customer experience, and identify growth opportunities, ultimately driving better business outcomes.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The conclusion of this EDA project is straightforward and concise. The data provides clear insights into customer preferences and demands.The analysis of the Airbnb dataset provided valuable insights into customer preferences, pricing trends, and location popularity.
#
# By leveraging these findings, Airbnb hosts and business stakeholders can optimize strategies, improve customer experiences, and expand their market reach effectively.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
